# %%
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# ## Prepare the data

# %%
df = pd.concat([pd.read_csv(f) for f in glob.glob('data/*.csv')], ignore_index = True)
df.head()
# Out:
#   001e06109416  1065.3788811188808  1530403200  52.572027972028  \
# 0          NaN                 NaN         NaN              NaN
# 1          NaN                 NaN         NaN              NaN
# 2          NaN                 NaN         NaN              NaN
# 3          NaN                 NaN         NaN              NaN
# 4          NaN                 NaN         NaN              NaN
#
#    avg_value_hrf bmp180 metsense       node_id      parameter pressure  \
# 0      -0.455178    NaN      NaN  001e06113107  concentration      NaN
# 1      19.377097    NaN      NaN  001e0610ee82    temperature      NaN
# 2      23.334481    NaN      NaN  001e0611536c      intensity      NaN
# 3      14.858500    NaN      NaN  001e0610ee43    temperature      NaN
# 4      17.963645    NaN      NaN  001e0610f6dd    temperature      NaN
#
#      sensor   subsystem temperature     timestamp
# 0        co   chemsense         NaN  1.525990e+09
# 1       at3   chemsense         NaN  1.525990e+09
# 2  tsl250rd  lightsense         NaN  1.525990e+09
# 3    htu21d    metsense         NaN  1.525990e+09
# 4    htu21d    metsense         NaN  1.525990e+09

# %%
df = df[['timestamp','node_id', 'subsystem','sensor','parameter', 'avg_value_hrf']]
#df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
df.head()
# Out:
#       timestamp       node_id   subsystem    sensor      parameter  \
# 0  1.525990e+09  001e06113107   chemsense        co  concentration
# 1  1.525990e+09  001e0610ee82   chemsense       at3    temperature
# 2  1.525990e+09  001e0611536c  lightsense  tsl250rd      intensity
# 3  1.525990e+09  001e0610ee43    metsense    htu21d    temperature
# 4  1.525990e+09  001e0610f6dd    metsense    htu21d    temperature
#
#    avg_value_hrf
# 0      -0.455178
# 1      19.377097
# 2      23.334481
# 3      14.858500
# 4      17.963645

# %%
dfNodes = pd.read_csv('nodes.csv', index_col=0)
dfNodes = dfNodes[['lat', 'lon']]
dfNodes.head()
# Out:
#                     lat        lon
# node_id
# 001e0610ba46  41.878377 -87.627678
# 001e0610ba3b  41.858136 -87.616055
# 001e0610ba8f  41.810342 -87.590228
# 001e0610ba16  41.891964 -87.611603
# 001e0610ba8b  41.780600 -87.586456

# %%
# Join the data to get lat & lon
dfData = df.join(dfNodes, on='node_id')
dfData.head()
# Out:
#       timestamp       node_id   subsystem    sensor      parameter  \
# 0  1.525990e+09  001e06113107   chemsense        co  concentration
# 1  1.525990e+09  001e0610ee82   chemsense       at3    temperature
# 2  1.525990e+09  001e0611536c  lightsense  tsl250rd      intensity
# 3  1.525990e+09  001e0610ee43    metsense    htu21d    temperature
# 4  1.525990e+09  001e0610f6dd    metsense    htu21d    temperature
#
#    avg_value_hrf        lat        lon
# 0      -0.455178  41.751142 -87.712990
# 1      19.377097  41.921405 -87.677766
# 2      23.334481  41.885750 -87.629690
# 3      14.858500  41.788608 -87.598713
# 4      17.963645  41.895355 -87.726064

# %%
# Create the independent variables
X = dfData[(dfData.subsystem=='alphasense') & (dfData.sensor == 'opc_n2') & (dfData.parameter == 'pm2_5')]
X = X[['timestamp','lat','lon']]
X = X.values

# %%
# Create the predicted variable
y = dfData[(dfData.subsystem=='alphasense') & (dfData.sensor == 'opc_n2') & (dfData.parameter == 'pm2_5')]
y = y['avg_value_hrf']

# %% [markdown]
# ### Build the predictive model

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import scipy as sp

# %%
# Split the data into a Training and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=45)

# %%
# KNN: Train on the training data using nearest neighbors
neigh = KNeighborsRegressor(n_neighbors=3, weights = 'distance')
neigh.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#           weights='distance')

# %%
# Check its accuracy by looking at the Root Mean Square Error of the KNN on the Test dataset
predVal = neigh.predict(X_test)
dfTest=pd.DataFrame([predVal,y_test]).transpose()
dfTest.columns=('p','y')
rmse = ((dfTest.p - dfTest.y) ** 2).mean() ** .5
print('RMSE = {} μg/m^3'.format(rmse))
print('Max = {}'.format(dfTest['y'].max()))
print('Min = {}'.format(dfTest['y'].min()))
print('Avg = {}'.format(dfTest['y'].mean()))
# Out:
# RMSE = 1.5234797763729575 μg/m^3
# Max = 36.963464285714274
# Min = 0.0
# Avg = 2.214686732628455

# %%
p
# Out:
# Coefficient of determination R^2 of the prediction = 0.8326757742836199

# %% [markdown]
# ### Save the model to disk for later use

# %%
import pickle

# %%
pickle.dump(neigh, open('model-knn.pickle', 'wb'))

# %%
# Example using the saved model
import time
loaded_model = pickle.load(open('model-knn.pickle', 'rb'))

# Predict given: [timestmap in unix time, lat, lon]
prediction = loaded_model.predict([[int(time.time()), 41.913830, -87.650910]])
print('Prediction = {} μg/m^3'.format(prediction[0]))
# Out:
# Prediction = 0.5169955721632646 μg/m^3

# %% [markdown]
# ## Available Parameters

# %%
df[['subsystem','sensor','parameter']].dropna().drop_duplicates()
# Out:
#         subsystem           sensor           parameter
# 0       chemsense               co       concentration
# 1       chemsense              at3         temperature
# 2      lightsense         tsl250rd           intensity
# 3        metsense           htu21d         temperature
# 5       chemsense              at1         temperature
# 6      lightsense         hmc5883l    magnetic_field_x
# 7      lightsense           tmp421         temperature
# 9       chemsense              at0         temperature
# 10     lightsense           ml8511           intensity
# 13      chemsense           lps25h         temperature
# 14      chemsense              no2       concentration
# 15       metsense         mma8452q      acceleration_x
# 16       metsense         mma8452q      acceleration_y
# 17       metsense           bmp180            pressure
# 18       metsense           tsys01         temperature
# 20     lightsense          hih6130         temperature
# 24       metsense          hih4030            humidity
# 25     lightsense         hmc5883l    magnetic_field_z
# 26     lightsense    apds_9006_020           intensity
# 28     lightsense         mlx75305           intensity
# 29      plantower          pms7003            pm25_atm
# 30      chemsense           lps25h            pressure
# 31     lightsense         tsl260rd           intensity
# 34       metsense         mma8452q      acceleration_z
# 35       metsense           tmp112         temperature
# 36      chemsense              so2       concentration
# 37       metsense           htu21d            humidity
# 41     lightsense          hih6130            humidity
# 51       metsense         tsl250rd           intensity
# 56       metsense    spv1840lr5h_b           intensity
# 70       metsense           bmp180         temperature
# 78     lightsense         hmc5883l    magnetic_field_y
# 86       metsense          pr103j2         temperature
# 97      chemsense            sht25         temperature
# 102     chemsense   reducing_gases       concentration
# 108     chemsense              at2         temperature
# 118     chemsense  oxidizing_gases       concentration
# 140     chemsense               o3       concentration
# 197     chemsense            sht25            humidity
# 222     chemsense              h2s       concentration
# 766    alphasense           opc_n2    sample_flow_rate
# 977    alphasense           opc_n2                pm10
# 1509   alphasense           opc_n2                 pm1
# 1593    plantower          pms7003            pm25_cf1
# 1796   alphasense           opc_n2     sampling_period
# 1825   alphasense           opc_n2               pm2_5
# 2237    plantower          pms7003  point_5um_particle
# 2352    plantower          pms7003             pm1_cf1
# 2609   alphasense           opc_n2                  fw
# 4267   alphasense           opc_n2                bins
# 4633    plantower          pms7003        1um_particle
# 4773    plantower          pms7003      2_5um_particle
# 6255    plantower          pms7003        5um_particle
# 6256    plantower          pms7003             pm1_atm
# 6968    plantower          pms7003            pm10_atm
# 7792    plantower          pms7003       10um_particle
# 10076   plantower          pms7003  point_3um_particle
# 11156   plantower          pms7003            pm10_cf1

# %% [markdown]
# ## Building a Grid
#
# Ok, that was a fun test, but we need to actually build a grid of coordinates to predict over a map.

# %%
max_lat = np.max(X[:, 1])
min_lat = np.min(X[:, 1])
max_lon = np.max(X[:, 2])
min_lon = np.min(X[:, 2])
print('Latitude Range: {} to {}'.format(min_lat, max_lat))
print('Longitude Range: {} to {}'.format(min_lon, max_lon))
# Out:
# Latitude Range: 41.722457 to 41.903632
# Longitude Range: -87.74526800000001 to -87.57535

# %%
resolution_lon = 10
resolution_lat = 10
grid_lon = np.linspace(min_lon, max_lon, resolution_lon)
grid_lat = np.linspace(min_lat, max_lat, resolution_lat)

# %%
grid_lat
# Out:
# array([41.722457  , 41.72428705, 41.7261171 , 41.72794715, 41.7297772 ,
#        41.73160725, 41.7334373 , 41.73526735, 41.7370974 , 41.73892745,
#        41.74075751, 41.74258756, 41.74441761, 41.74624766, 41.74807771,
#        41.74990776, 41.75173781, 41.75356786, 41.75539791, 41.75722796,
#        41.75905801, 41.76088806, 41.76271811, 41.76454816, 41.76637821,
#        41.76820826, 41.77003831, 41.77186836, 41.77369841, 41.77552846,
#        41.77735852, 41.77918857, 41.78101862, 41.78284867, 41.78467872,
#        41.78650877, 41.78833882, 41.79016887, 41.79199892, 41.79382897,
#        41.79565902, 41.79748907, 41.79931912, 41.80114917, 41.80297922,
#        41.80480927, 41.80663932, 41.80846937, 41.81029942, 41.81212947,
#        41.81395953, 41.81578958, 41.81761963, 41.81944968, 41.82127973,
#        41.82310978, 41.82493983, 41.82676988, 41.82859993, 41.83042998,
#        41.83226003, 41.83409008, 41.83592013, 41.83775018, 41.83958023,
#        41.84141028, 41.84324033, 41.84507038, 41.84690043, 41.84873048,
#        41.85056054, 41.85239059, 41.85422064, 41.85605069, 41.85788074,
#        41.85971079, 41.86154084, 41.86337089, 41.86520094, 41.86703099,
#        41.86886104, 41.87069109, 41.87252114, 41.87435119, 41.87618124,
#        41.87801129, 41.87984134, 41.88167139, 41.88350144, 41.88533149,
#        41.88716155, 41.8889916 , 41.89082165, 41.8926517 , 41.89448175,
#        41.8963118 , 41.89814185, 41.8999719 , 41.90180195, 41.903632  ])

# %% [markdown]
# ## Try building a model using Kriging
#     pip install pykrige

# %%
import pykrige.kriging_tools as kt
from pykrige.ok import OrdinaryKriging

# %%
timestamps= X[:, 0]
latitudes = X[:, 1]
longitudes= X[:, 2]

# %%
OK = OrdinaryKriging(longitudes, latitudes, y, variogram_model='linear',
                     verbose=False, enable_plotting=False)

# %%
# Predict
z, ss = OK.execute('grid', grid_lon, grid_lat)

# %%
grid_lon
# Out:
# array([-87.745268  , -87.72638822, -87.70750844, -87.68862867,
#        -87.66974889, -87.65086911, -87.63198933, -87.61310956,
#        -87.59422978, -87.57535   ])

# %%
import folium
from folium import plugins
from folium.plugins import HeatMap

# %%
concentrations = []
for x in range(z.shape[0]):
    for y in range(z.shape[1]):
        concentrations.append([
                               grid_lat[y], 
                               grid_lon[x], 
                               z[x,y]])

# %%
mapPM25 = folium.Map(location=[41.8781, -87.6298], zoom_start = 11)
HeatMap(concentrations).add_to(mapPM25)
mapPM25
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
